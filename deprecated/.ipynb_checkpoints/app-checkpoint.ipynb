# %% [markdown]
# # Test File to Explore AWS Textract Parsing Behavior

# %% [markdown]
# ### Include necessary imports in the cell below:

# %%
import os
import time
import json
import boto3
import pandas as pd
from dotenv import load_dotenv
from openai import OpenAIError, RateLimitError
from langchain import HuggingFaceHub, PromptTemplate
import tiktoken
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import time
#       3 import json
# ----> 4 import boto3
#       5 import pandas as pd
#       6 from dotenv import load_dotenv
#
# ModuleNotFoundError: No module named 'boto3'

# %% [markdown]
# ### Function Call to Retrieve Entire Document Analysis
# - Requires a job ID from previous call

# %%
# Initialize Textract client
textract = boto3.client('textract', region_name='us-east-1')

def get_all_document_analysis(job_id):
    results = []
    next_token = None

    while True:
        # Prepare parameters for the API call
        params = {
            'JobId': job_id
        }
        
        if next_token:
            params['NextToken'] = next_token  # Include NextToken if available

        # Call the Textract API
        print(params)
        response = textract.get_document_analysis(**params)

        # Append the blocks to results
        results.extend(response.get('Blocks', []))

        # Check for NextToken in the response
        next_token = response.get('NextToken')

        # Break if there's no more pages
        if not next_token:
            break

    return results

# Usage
job_id = 'a60cf021227e3eb17e2288f6c104f782d0a36cb199f99f46cfefc813224640e3'
all_results = get_all_document_analysis(job_id)

with open('textract_output_next_page.json', 'w') as json_file:
    json.dump(all_results, json_file, indent=4)
# Out:
# {'JobId': 'a60cf021227e3eb17e2288f6c104f782d0a36cb199f99f46cfefc813224640e3'}
# {'JobId': 'a60cf021227e3eb17e2288f6c104f782d0a36cb199f99f46cfefc813224640e3', 'NextToken': 'VDZS/xOfdp0zpWvvVE4/0e6UIUK7SSlFUKY6eu2GHYGA4X8D9jHW0tzK6okH4PYcKiWliGAJtET/fEHnjdPnQGpwniOJY+2GD0i/w6Gp/Or9LFY3byZdaYk+BgiAynDB4lAGx3s='}

# %%
# Load the JSON file containing the Textract output
with open('textract_output.json', 'r') as json_file:
    textract_response = json.load(json_file)

def extract_tables_from_json(response):
    # Create a dictionary to map Block Ids to Blocks for faster lookup
    block_map = {block['Id']: block for block in response['Blocks']}
    
    tables = []
    current_table = {}
    current_page = 1
    
    for block in response['Blocks']:
        if block['BlockType'] == 'TABLE':
            table = {}
            for relationship in block.get('Relationships', []):
                if relationship['Type'] == 'CHILD':
                    cell_ids = relationship['Ids']
                    for cell_id in cell_ids:
                        cell_block = block_map.get(cell_id)
                        if cell_block and cell_block['BlockType'] == 'CELL':
                            row = cell_block['RowIndex']
                            col = cell_block['ColumnIndex']
                            cell_text = ''
                            
                            # Get the text from the WORD blocks inside the CELL block
                            for rel in cell_block.get('Relationships', []):
                                if rel['Type'] == 'CHILD':
                                    for word_id in rel['Ids']:
                                        word_block = block_map.get(word_id)
                                        if word_block and word_block['BlockType'] == 'WORD':
                                            cell_text += word_block['Text'] + ' '
                            
                            # Add the cell text to the table dictionary
                            if row not in table:
                                table[row] = {}
                            table[row][col] = cell_text.strip()
            
            # Check if the table belongs to the current page
            if block.get('Page') == current_page:
                # Merge current table with the new one if it's on the same page
                current_table = merge_tables(current_table, table)
            else:
                # If page number changes, push the current table to the list and reset
                if current_table:
                    tables.append(current_table)
                current_table = table
                current_page = block.get('Page', current_page)

    # Append the last table after iteration
    if current_table:
        tables.append(current_table)
        
    return tables

def merge_tables(existing_table, new_table):
    """Merges two tables by appending rows from the new table to the existing table."""
    merged_table = existing_table.copy()
    
    for row, cols in new_table.items():
        if row in merged_table:
            # If row exists, merge column values
            merged_table[row].update(cols)
        else:
            # Add the new row if not present
            merged_table[row] = cols
            
    return merged_table

# %%
# Load the JSON file containing the Textract output
with open('textract_output.json', 'r') as json_file:
    textract_response = json.load(json_file)

def extract_tables_from_json(response):
    # Create a dictionary to map Block Ids to Blocks for faster lookup
    block_map = {block['Id']: block for block in response['Blocks']}
    
    tables = []
    for block in response['Blocks']:
        if block['BlockType'] == 'TABLE':
            table = {}
            for relationship in block.get('Relationships', []):
                if relationship['Type'] == 'CHILD':
                    cell_ids = relationship['Ids']
                    for cell_id in cell_ids:
                        cell_block = block_map.get(cell_id)
                        if cell_block and cell_block['BlockType'] == 'CELL':
                            row = cell_block['RowIndex']
                            col = cell_block['ColumnIndex']
                            cell_text = ''
                            
                            # Get the text from the WORD blocks inside the CELL block
                            for rel in cell_block.get('Relationships', []):
                                if rel['Type'] == 'CHILD':
                                    for word_id in rel['Ids']:
                                        word_block = block_map.get(word_id)
                                        if word_block and word_block['BlockType'] == 'WORD':
                                            cell_text += word_block['Text'] + ' '
                            
                            # Add the cell text to the table dictionary
                            if row not in table:
                                table[row] = {}
                            table[row][col] = cell_text.strip()
            tables.append(table)
    return tables

# %%
# Call the function to extract tables
tables = extract_tables_from_json(textract_response)

# Display the extracted table data as DataFrames for better readability
for table in tables:
    # Convert the extracted table into a DataFrame
    df = pd.DataFrame.from_dict(table, orient='index')
    #print(df)

# Set the first row as the column headers
df.columns = df.iloc[0]  # Use the first row as header
df = df.drop(df.index[0])  # Drop the first row from the DataFrame

# Remove duplicate claims
df = df.drop_duplicates(subset='Claim Number')

# %%
df
# Out:
# 1   Claim Number Policy Insured Code  \
# 2   150123008611              EKA119
# 4   161216008812              EKAA4G
# 6   190806002768              EKAA4G
# 8   190927007769              EKAA4G
# 10  200118002308              EKA119
# 12  200206005764              EKA894
# 14  200218006998              EKA965
#
# 1                                Dealer / Lessee Name                VIN  \
# 2                           ANDERSON FORD OF ST JOSEP  2LMDU88C77BJ14427
# 4                       ANDERSON FORD OF GRAND ISLAND  2LMHJ5AT5CBL55030
# 6                       ANDERSON FORD OF GRAND ISLAND              MULTI
# 8                       ANDERSON FORD OF GRAND ISLAND  2FMPK4J91KBB61371
# 10                          ANDERSON FORD OF ST JOSEP  1FT8W3DT3HEC08556
# 12  ANDERSON FORD OF LINCOLN / ANDERSON LINCOLN OF...  JN8AT2MV6HW016228
# 14                                       ANDERSON KIA  5XYPHDA52LG647197
#
# 1  Subline State / Province       Cause of Loss   Loss Date Claim Close Date  \
# 2   FCNAUS               MO           Collision  01/23/2015       02/19/2021
# 4   FCNAUS               NE           Collision  12/16/2016
# 6   FCNAUS               NE                Wind  08/06/2019       12/23/2020
# 8   FCNAUS               NE               Theft  09/27/2019
# 10  FCNAUS               MO               Theft  02/18/2017       09/17/2020
# 12  FCNAUS               NE           Collision  02/06/2020       02/11/2020
# 14  FCNAUS               MO  All Other (non WX)  02/18/2020       04/07/2020
#
# 1  Units Indemnity Payments Indemnity Expenses Net Insurance Recoveries  \
# 2      0              $0.00              $0.00                    $0.00
# 4      0              $0.00            $607.50                $2,002.46
# 6      8              $0.00              $0.00                $1,677.00
# 8      1              $0.00            $586.07               $35,200.00
# 10     1              $0.00              $0.00               $27,750.00
# 12     1              $0.00              $0.00                    $0.00
# 14     1              $0.00              $0.00                    $0.00
#
# 1  Indemnity Payments Net
# 2                   $0.00
# 4                 $607.50
# 6                   $0.00
# 8                 $586.07
# 10                  $0.00
# 12                  $0.00
# 14                  $0.00

# %%
df['text'] = df.apply(lambda x: ' '.join(x.astype(str)), axis=1)
df.iloc[1]['text']
# Out:
# '161216008812 EKAA4G ANDERSON FORD OF GRAND ISLAND 2LMHJ5AT5CBL55030 FCNAUS NE Collision 12/16/2016  0 $0.00 $607.50 $2,002.46 $607.50'

# %%
import re

# Regex pattern to match prices
pattern = r'\$([0-9]{1,3}(?:,[0-9]{3})*|[0-9]+)(\.[0-9]{2})?'

# Removing prices from the text column
df['text'] = df['text'].apply(lambda x: re.sub(pattern, '', x))
df.iloc[1]['text']
# Out:
# '161216008812 EKAA4G ANDERSON FORD OF GRAND ISLAND 2LMHJ5AT5CBL55030 FCNAUS NE Collision 12/16/2016  0    '

# %%
# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("roberta-base")
model = AutoModelForSequenceClassification.from_pretrained("roberta-base", num_labels=2)  # 2 labels: relevant or not

# Define the prompt (your task description and data)
prompt_template = """
Given the following claims data, remove all claims not relevant to open dealer lot coverage or that involve third-party coverage.
Return the Claim Number of the remaining claims along with a short description of why each was included.
CLAIM DATA GOES HERE
"""

# Function to count tokens using Hugging Face tokenizer
def count_tokens(text):
    tokens = tokenizer.encode(text, return_tensors="pt")
    return tokens.size(1)  # Return the token count

# Function to batch the DataFrame
def batch_dataframe(df, max_tokens, prompt_tokens):
    batches = []
    current_batch = []
    current_tokens = 0

    for _, row in df.iterrows():
        row_str = row.to_string(index=False, header=False)  # Convert row to string
        row_tokens = count_tokens(row_str)

        # Check if adding this row exceeds the limit
        if current_tokens + row_tokens + prompt_tokens > max_tokens:
            if current_batch:  # If there's already data in the current batch
                batches.append(pd.DataFrame(current_batch))
                current_batch = []  # Reset current batch
                current_tokens = 0

        current_batch.append(row)
        current_tokens += row_tokens

    if current_batch:  # Add any remaining data
        batches.append(pd.DataFrame(current_batch))

    return batches

# Generate responses for each batch
def process_batches(batches, prompt_template, model, tokenizer, max_length=200):
    responses = []
    for i, batch in enumerate(batches):
        data_string = batch.to_string(index=False, header=True)  # Create the data string from the batch
        
        # Create the full prompt with data included
        full_prompt = prompt_template.replace("CLAIM DATA GOES HERE", data_string)  # Replace placeholder with data
        
        try:
            response = generate_response(full_prompt, model, tokenizer, max_length)
            responses.append((i + 1, response))  # Append the batch number and response
        except Exception as e:
            print(f"Error processing batch {i + 1}: {e}")
    
    return responses

# Function to generate a response from the model
def generate_response(prompt, model, tokenizer, max_length=200):
    # Tokenize the input prompt
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True)

    # Generate the output
    outputs = model.generate(inputs["input_ids"], max_length=max_length)

    # Decode the generated tokens to get the output text
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

# Calculate prompt tokens and convert the entire DataFrame into batches
prompt_tokens = count_tokens(prompt_template)
max_tokens = 512  # Adjust based on model limit
df_batches = batch_dataframe(df, max_tokens, prompt_tokens)

# Process the batches and get responses
responses = process_batches(df_batches, prompt_template, model, tokenizer)

# Print or handle the responses
for batch_num, response in responses:
    print(f"Response for batch {batch_num}:")
    print(response)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Token indices sequence length is longer than the specified maximum sequence length for this model (629 > 512). Running this sequence through the model will result in indexing errors
# Response for batch 1:
# ['Relevant']
# Response for batch 2:
# ['Relevant']
# Response for batch 3:
# ['Relevant']
# Response for batch 4:
# ['Relevant']
# Response for batch 5:
# ['Relevant']
# Response for batch 6:
# ['Relevant']
# Response for batch 7:
# ['Relevant']

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("llmware/industry-bert-insurance-v0.1")
model = AutoModelForSequenceClassification.from_pretrained("llmware/industry-bert-insurance-v0.1")

def create_prompt(claim):
    return f"Evaluate the following claim for relevance to open dealer lot coverage excluding third parties:{claim}\nIs this claim relevant? (yes/no)"
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at llmware/industry-bert-insurance-v0.1 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import torch.nn.functional as F
# Classify claims
def classify_claims(df):
    relevant_claims = []

    for index, row in df.iterrows():
        prompt = create_prompt(row)
        inputs = tokenizer(prompt, return_tensors="pt")

        # Perform inference
        with torch.no_grad():
            outputs = model(**inputs)
            logits = outputs.logits
            probabilities = F.softmax(logits, dim=1)  # Apply softmax to get probabilities
            
            # Print logits and probabilities for debugging
            print(f"Claim {row['Claim Number']} Logits: {logits}, Probabilities: {probabilities}")

            predicted_class = logits.argmax().item()  # Get the predicted class index

        # Assuming class index 1 is "relevant"
        if predicted_class == 1:  # Adjust based on your model's output class index
            relevant_claims.append(row)

    return pd.DataFrame(relevant_claims)

# Get relevant claims
relevant_claims_df = classify_claims(df)

# Print the filtered claims
print("Filtered Claims:")
print(relevant_claims_df)
# Out:
# Claim 150123008611 Logits: tensor([[ 0.1962, -0.2636]]), Probabilities: tensor([[0.6130, 0.3870]])
# Claim 161216008812 Logits: tensor([[ 0.1819, -0.2930]]), Probabilities: tensor([[0.6165, 0.3835]])
# Claim 190806002768 Logits: tensor([[ 0.1818, -0.2586]]), Probabilities: tensor([[0.6084, 0.3916]])
# Claim 190927007769 Logits: tensor([[ 0.1822, -0.2629]]), Probabilities: tensor([[0.6095, 0.3905]])
# Claim 200118002308 Logits: tensor([[ 0.2032, -0.2967]]), Probabilities: tensor([[0.6224, 0.3776]])
# Claim 200206005764 Logits: tensor([[ 0.1700, -0.3021]]), Probabilities: tensor([[0.6159, 0.3841]])
# Claim 200218006998 Logits: tensor([[ 0.1874, -0.2653]]), Probabilities: tensor([[0.6113, 0.3887]])
# Filtered Claims:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from google.cloud import documentai_v1 as documentai
from google.oauth2 import service_account
import base64
import json

# Prepare variables
project_id = 'verdant-cargo-443521-j3'
location = 'us'
processor_id = 'f2db9bcc34ed8bb5'

file_path = '/path/to/local/file/.pdf'
mime_type = 'application/pdf'

# Load the service account key
credentials = service_account.Credentials.from_service_account_file(
    "../secret/verdant-cargo-443521-j3-8d56893a2e2e.json"
)

opts = {
    "api_endpoint" : f"{location}-documentai.googleapis.com"
}

# Configure the processor client (i.e. prepare the endpoint)
client = documentai.DocumentProcessorServiceClient(client_options=opts, credentials=credentials)

name = client.processor_path(project_id, location, processor_id)

#Open File
with open('../classification_model/loss_runs/input/Copy of Stoler of Queens, Inc dba Silver Star Motors - Loss Run - 942024.pdf', 'rb') as pdf_file:
    pdf_data = pdf_file.read()

# Construct the request
raw_document = documentai.RawDocument(content=pdf_data, mime_type=mime_type)

request = documentai.ProcessRequest(name=name, raw_document=raw_document)

# Analyze output
result = client.process_document(request=request)

document = result.document

# %%
print(document)
for page in document.pages:
    for table in page.tables:
        #print(table)
        for row in table.header_rows:
            row_text = ""
            for cell in row.cells:
                cell_text = ""
                for text_segment in cell.layout.text_anchor.text_segments:
                    cell_text += document.text[text_segment.start_index:text_segment.end_index]
                row_text += cell_text.strip() + ' '
                
            #print(f'{row_text}\n')
# Out:
# uri: ""
# mime_type: "application/pdf"
# text: "RISK POINT\nRisk Point Program\nLoss History\nEXCELLENCE INTEGRITY PROFESSIONALISM\nAccount:\nStoler of Queens, Inc dba Silver Star Motors\nAccount #:\n100046290\nCity, State Zip:\nCoverage Period:\nLong Island City, New York 11101\n3/28/2024 to 3/28/2025\n9/4/2024\nValued as of:\nCause of\nDate of\nClaim Number\nInsured Name\nDescription of Accident\nIndemnity\nExpense\nRecovery\nStatus\nLoss\nLoss\n907885-CB\nStoler of Queens, Inc dba\nCollision\n17,143.90\n240.00\n0.00\nClosed\nSilver Star Motors\n7/25/2024 IVD trying to park vehicle\nin stacker lift that they\npark the cars in, as he\nwas trying to back the car\nin, his foot got stuck\nwhile reversing and hit\nthe stackers.\n907814-CB\nStoler of Queens, Inc dba\nCollision\n6/21/2024 Rental was involved in\n0.00\n400.00\n0.00\nClosed\nSilver Star Motors\ncollision while being used\nas a service loaner.\n907812-CB\nStoler of Queens, Inc dba\nCollision\n1,300.00\n0.00\nOpen\n4/23/2024 Customer was involved in 6,262.12\na collision while in loaner\nSilver Star Motors\n1| Page\n9/4/2024\n"
# pages {
#   page_number: 1
#   dimension {
#     width: 2275
#     height: 1758
#     unit: "pixels"
#   }
#   layout {
#     text_anchor {
#       text_segments {
#         end_index: 991
#       }
#     }
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 2275
#       }
#       vertices {
#         x: 2275
#         y: 1758
#       }
#       vertices {
#         y: 1758
#       }
#       normalized_vertices {
#       }
#       normalized_vertices {
#         x: 1
#       }
#       normalized_vertices {
#         x: 1
#         y: 1
#       }
#       normalized_vertices {
#         y: 1
#       }
#     }
#     orientation: PAGE_UP
#   }
#   detected_languages {
#     language_code: "en"
#     confidence: 0.826606929
#   }
#   detected_languages {
#     language_code: "und"
#     confidence: 0.0982943699
#   }
#   detected_languages {
#     language_code: "no"
#     confidence: 0.0750987157
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 11
#         }
#       }
#       confidence: 0.972773612
#       bounding_poly {
#         vertices {
#           x: 318
#           y: 174
#         }
#         vertices {
#           x: 927
#           y: 186
#         }
#         vertices {
#           x: 925
#           y: 268
#         }
#         vertices {
#           x: 316
#           y: 256
#         }
#         normalized_vertices {
#           x: 0.139780223
#           y: 0.0989761129
#         }
#         normalized_vertices {
#           x: 0.407472521
#           y: 0.105802044
#         }
#         normalized_vertices {
#           x: 0.406593412
#           y: 0.152445957
#         }
#         normalized_vertices {
#           x: 0.1389011
#           y: 0.145620018
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 11
#           end_index: 30
#         }
#       }
#       confidence: 0.981170893
#       bounding_poly {
#         vertices {
#           x: 1309
#           y: 159
#         }
#         vertices {
#           x: 1914
#           y: 173
#         }
#         vertices {
#           x: 1913
#           y: 231
#         }
#         vertices {
#           x: 1308
#           y: 217
#         }
#         normalized_vertices {
#           x: 0.575384617
#           y: 0.0904436857
#         }
#         normalized_vertices {
#           x: 0.841318667
#           y: 0.0984072834
#         }
#         normalized_vertices {
#           x: 0.840879142
#           y: 0.131399319
#         }
#         normalized_vertices {
#           x: 0.574945033
#           y: 0.123435721
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 30
#           end_index: 43
#         }
#       }
#       confidence: 0.985181749
#       bounding_poly {
#         vertices {
#           x: 1488
#           y: 252
#         }
#         vertices {
#           x: 1739
#           y: 259
#         }
#         vertices {
#           x: 1738
#           y: 295
#         }
#         vertices {
#           x: 1487
#           y: 288
#         }
#         normalized_vertices {
#           x: 0.654065907
#           y: 0.143344715
#         }
#         normalized_vertices {
#           x: 0.764395595
#           y: 0.147326514
#         }
#         normalized_vertices {
#           x: 0.76395607
#           y: 0.167804316
#         }
#         normalized_vertices {
#           x: 0.653626382
#           y: 0.163822532
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 43
#           end_index: 80
#         }
#       }
#       confidence: 0.983066082
#       bounding_poly {
#         vertices {
#           x: 325
#           y: 281
#         }
#         vertices {
#           x: 913
#           y: 281
#         }
#         vertices {
#           x: 913
#           y: 299
#         }
#         vertices {
#           x: 325
#           y: 299
#         }
#         normalized_vertices {
#           x: 0.142857149
#           y: 0.159840733
#         }
#         normalized_vertices {
#           x: 0.401318669
#           y: 0.159840733
#         }
#         normalized_vertices {
#           x: 0.401318669
#           y: 0.170079634
#         }
#         normalized_vertices {
#           x: 0.142857149
#           y: 0.170079634
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 80
#           end_index: 89
#         }
#       }
#       confidence: 0.964407682
#       bounding_poly {
#         vertices {
#           x: 119
#           y: 386
#         }
#         vertices {
#           x: 232
#           y: 386
#         }
#         vertices {
#           x: 232
#           y: 406
#         }
#         vertices {
#           x: 119
#           y: 406
#         }
#         normalized_vertices {
#           x: 0.0523076914
#           y: 0.219567686
#         }
#         normalized_vertices {
#           x: 0.101978019
#           y: 0.219567686
#         }
#         normalized_vertices {
#           x: 0.101978019
#           y: 0.230944261
#         }
#         normalized_vertices {
#           x: 0.0523076914
#           y: 0.230944261
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 89
#           end_index: 134
#         }
#       }
#       confidence: 0.97918874
#       bounding_poly {
#         vertices {
#           x: 613
#           y: 385
#         }
#         vertices {
#           x: 1175
#           y: 385
#         }
#         vertices {
#           x: 1175
#           y: 409
#         }
#         vertices {
#           x: 613
#           y: 409
#         }
#         normalized_vertices {
#           x: 0.269450545
#           y: 0.218998864
#         }
#         normalized_vertices {
#           x: 0.516483545
#           y: 0.218998864
#         }
#         normalized_vertices {
#           x: 0.516483545
#           y: 0.232650742
#         }
#         normalized_vertices {
#           x: 0.269450545
#           y: 0.232650742
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 134
#           end_index: 145
#         }
#       }
#       confidence: 0.966734529
#       bounding_poly {
#         vertices {
#           x: 119
#           y: 426
#         }
#         vertices {
#           x: 256
#           y: 427
#         }
#         vertices {
#           x: 256
#           y: 446
#         }
#         vertices {
#           x: 119
#           y: 445
#         }
#         normalized_vertices {
#           x: 0.0523076914
#           y: 0.242320821
#         }
#         normalized_vertices {
#           x: 0.112527475
#           y: 0.242889643
#         }
#         normalized_vertices {
#           x: 0.112527475
#           y: 0.253697395
#         }
#         normalized_vertices {
#           x: 0.0523076914
#           y: 0.253128558
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 145
#           end_index: 155
#         }
#       }
#       confidence: 0.990854204
#       bounding_poly {
#         vertices {
#           x: 615
#           y: 426
#         }
#         vertices {
#           x: 757
#           y: 426
#         }
#         vertices {
#           x: 757
#           y: 445
#         }
#         vertices {
#           x: 615
#           y: 445
#         }
#         normalized_vertices {
#           x: 0.270329684
#           y: 0.242320821
#         }
#         normalized_vertices {
#           x: 0.332747251
#           y: 0.242320821
#         }
#         normalized_vertices {
#           x: 0.332747251
#           y: 0.253128558
#         }
#         normalized_vertices {
#           x: 0.270329684
#           y: 0.253128558
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 155
#           end_index: 189
#         }
#       }
#       confidence: 0.980165899
#       bounding_poly {
#         vertices {
#           x: 119
#           y: 466
#         }
#         vertices {
#           x: 337
#           y: 464
#         }
#         vertices {
#           x: 338
#           y: 529
#         }
#         vertices {
#           x: 120
#           y: 531
#         }
#         normalized_vertices {
#           x: 0.0523076914
#           y: 0.265073955
#         }
#         normalized_vertices {
#           x: 0.148131862
#           y: 0.263936281
#         }
#         normalized_vertices {
#           x: 0.148571432
#           y: 0.300910115
#         }
#         normalized_vertices {
#           x: 0.0527472533
#           y: 0.302047789
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 189
#           end_index: 254
#         }
#       }
#       confidence: 0.98825866
#       bounding_poly {
#         vertices {
#           x: 613
#           y: 463
#         }
#         vertices {
#           x: 1038
#           y: 463
#         }
#         vertices {
#           x: 1038
#           y: 569
#         }
#         vertices {
#           x: 613
#           y: 569
#         }
#         normalized_vertices {
#           x: 0.269450545
#           y: 0.263367474
#         }
#         normalized_vertices {
#           x: 0.456263751
#           y: 0.263367474
#         }
#         normalized_vertices {
#           x: 0.456263751
#           y: 0.323663265
#         }
#         normalized_vertices {
#           x: 0.269450545
#           y: 0.323663265
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 254
#           end_index: 268
#         }
#       }
#       confidence: 0.979383528
#       bounding_poly {
#         vertices {
#           x: 118
#           y: 543
#         }
#         vertices {
#           x: 286
#           y: 544
#         }
#         vertices {
#           x: 286
#           y: 566
#         }
#         vertices {
#           x: 118
#           y: 565
#         }
#         normalized_vertices {
#           x: 0.0518681332
#           y: 0.308873713
#         }
#         normalized_vertices {
#           x: 0.125714287
#           y: 0.30944255
#         }
#         normalized_vertices {
#           x: 0.125714287
#           y: 0.321956784
#         }
#         normalized_vertices {
#           x: 0.0518681332
#           y: 0.321387947
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 268
#           end_index: 277
#         }
#       }
#       confidence: 0.975615501
#       bounding_poly {
#         vertices {
#           x: 764
#           y: 625
#         }
#         vertices {
#           x: 877
#           y: 624
#         }
#         vertices {
#           x: 877
#           y: 644
#         }
#         vertices {
#           x: 764
#           y: 645
#         }
#         normalized_vertices {
#           x: 0.335824162
#           y: 0.355517626
#         }
#         normalized_vertices {
#           x: 0.3854945
#           y: 0.354948819
#         }
#         normalized_vertices {
#           x: 0.3854945
#           y: 0.366325378
#         }
#         normalized_vertices {
#           x: 0.335824162
#           y: 0.366894186
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 277
#           end_index: 285
#         }
#       }
#       confidence: 0.941919327
#       bounding_poly {
#         vertices {
#           x: 954
#           y: 624
#         }
#         vertices {
#           x: 1050
#           y: 622
#         }
#         vertices {
#           x: 1050
#           y: 644
#         }
#         vertices {
#           x: 954
#           y: 646
#         }
#         normalized_vertices {
#           x: 0.41934067
#           y: 0.354948819
#         }
#         normalized_vertices {
#           x: 0.461538464
#           y: 0.353811145
#         }
#         normalized_vertices {
#           x: 0.461538464
#           y: 0.366325378
#         }
#         normalized_vertices {
#           x: 0.41934067
#           y: 0.367463022
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 285
#           end_index: 298
#         }
#       }
#       confidence: 0.982179284
#       bounding_poly {
#         vertices {
#           x: 125
#           y: 642
#         }
#         vertices {
#           x: 315
#           y: 643
#         }
#         vertices {
#           x: 315
#           y: 665
#         }
#         vertices {
#           x: 125
#           y: 664
#         }
#         normalized_vertices {
#           x: 0.0549450554
#           y: 0.365187705
#         }
#         normalized_vertices {
#           x: 0.138461545
#           y: 0.365756541
#         }
#         normalized_vertices {
#           x: 0.138461545
#           y: 0.378270775
#         }
#         normalized_vertices {
#           x: 0.0549450554
#           y: 0.377701938
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 298
#           end_index: 311
#         }
#       }
#       confidence: 0.980144799
#       bounding_poly {
#         vertices {
#           x: 438
#           y: 644
#         }
#         vertices {
#           x: 622
#           y: 644
#         }
#         vertices {
#           x: 622
#           y: 664
#         }
#         vertices {
#           x: 438
#           y: 664
#         }
#         normalized_vertices {
#           x: 0.192527473
#           y: 0.366325378
#         }
#         normalized_vertices {
#           x: 0.273406595
#           y: 0.366325378
#         }
#         normalized_vertices {
#           x: 0.273406595
#           y: 0.377701938
#         }
#         normalized_vertices {
#           x: 0.192527473
#           y: 0.377701938
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 311
#           end_index: 335
#         }
#       }
#       confidence: 0.982776225
#       bounding_poly {
#         vertices {
#           x: 1114
#           y: 643
#         }
#         vertices {
#           x: 1419
#           y: 639
#         }
#         vertices {
#           x: 1419
#           y: 665
#         }
#         vertices {
#           x: 1114
#           y: 669
#         }
#         normalized_vertices {
#           x: 0.489670336
#           y: 0.365756541
#         }
#         normalized_vertices {
#           x: 0.623736262
#           y: 0.363481224
#         }
#         normalized_vertices {
#           x: 0.623736262
#           y: 0.378270775
#         }
#         normalized_vertices {
#           x: 0.489670336
#           y: 0.380546063
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 335
#           end_index: 345
#         }
#       }
#       confidence: 0.982938
#       bounding_poly {
#         vertices {
#           x: 1484
#           y: 644
#         }
#         vertices {
#           x: 1619
#           y: 643
#         }
#         vertices {
#           x: 1619
#           y: 667
#         }
#         vertices {
#           x: 1484
#           y: 668
#         }
#         normalized_vertices {
#           x: 0.652307689
#           y: 0.366325378
#         }
#         normalized_vertices {
#           x: 0.711648345
#           y: 0.365756541
#         }
#         normalized_vertices {
#           x: 0.711648345
#           y: 0.379408419
#         }
#         normalized_vertices {
#           x: 0.652307689
#           y: 0.379977256
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 345
#           end_index: 353
#         }
#       }
#       confidence: 0.9795807
#       bounding_poly {
#         vertices {
#           x: 1705
#           y: 645
#         }
#         vertices {
#           x: 1812
#           y: 645
#         }
#         vertices {
#           x: 1812
#           y: 669
#         }
#         vertices {
#           x: 1705
#           y: 669
#         }
#         normalized_vertices {
#           x: 0.749450564
#           y: 0.366894186
#         }
#         normalized_vertices {
#           x: 0.796483517
#           y: 0.366894186
#         }
#         normalized_vertices {
#           x: 0.796483517
#           y: 0.380546063
#         }
#         normalized_vertices {
#           x: 0.749450564
#           y: 0.380546063
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 353
#           end_index: 362
#         }
#       }
#       confidence: 0.978332043
#       bounding_poly {
#         vertices {
#           x: 1905
#           y: 646
#         }
#         vertices {
#           x: 2027
#           y: 646
#         }
#         vertices {
#           x: 2027
#           y: 669
#         }
#         vertices {
#           x: 1905
#           y: 669
#         }
#         normalized_vertices {
#           x: 0.837362647
#           y: 0.367463022
#         }
#         normalized_vertices {
#           x: 0.890989
#           y: 0.367463022
#         }
#         normalized_vertices {
#           x: 0.890989
#           y: 0.380546063
#         }
#         normalized_vertices {
#           x: 0.837362647
#           y: 0.380546063
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 362
#           end_index: 369
#         }
#       }
#       confidence: 0.976591349
#       bounding_poly {
#         vertices {
#           x: 2091
#           y: 645
#         }
#         vertices {
#           x: 2174
#           y: 645
#         }
#         vertices {
#           x: 2174
#           y: 664
#         }
#         vertices {
#           x: 2091
#           y: 664
#         }
#         normalized_vertices {
#           x: 0.919120908
#           y: 0.366894186
#         }
#         normalized_vertices {
#           x: 0.955604374
#           y: 0.366894186
#         }
#         normalized_vertices {
#           x: 0.955604374
#           y: 0.377701938
#         }
#         normalized_vertices {
#           x: 0.919120908
#           y: 0.377701938
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 369
#           end_index: 374
#         }
#       }
#       confidence: 0.875503242
#       bounding_poly {
#         vertices {
#           x: 794
#           y: 664
#         }
#         vertices {
#           x: 849
#           y: 665
#         }
#         vertices {
#           x: 849
#           y: 684
#         }
#         vertices {
#           x: 794
#           y: 683
#         }
#         normalized_vertices {
#           x: 0.349010974
#           y: 0.377701938
#         }
#         normalized_vertices {
#           x: 0.373186827
#           y: 0.378270775
#         }
#         normalized_vertices {
#           x: 0.373186827
#           y: 0.389078498
#         }
#         normalized_vertices {
#           x: 0.349010974
#           y: 0.388509661
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 374
#           end_index: 379
#         }
#       }
#       confidence: 0.957087
#       bounding_poly {
#         vertices {
#           x: 975
#           y: 665
#         }
#         vertices {
#           x: 1030
#           y: 665
#         }
#         vertices {
#           x: 1030
#           y: 683
#         }
#         vertices {
#           x: 975
#           y: 683
#         }
#         normalized_vertices {
#           x: 0.428571433
#           y: 0.378270775
#         }
#         normalized_vertices {
#           x: 0.452747256
#           y: 0.378270775
#         }
#         normalized_vertices {
#           x: 0.452747256
#           y: 0.388509661
#         }
#         normalized_vertices {
#           x: 0.428571433
#           y: 0.388509661
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 379
#           end_index: 389
#         }
#       }
#       confidence: 0.986462
#       bounding_poly {
#         vertices {
#           x: 119
#           y: 703
#         }
#         vertices {
#           x: 258
#           y: 703
#         }
#         vertices {
#           x: 258
#           y: 723
#         }
#         vertices {
#           x: 119
#           y: 723
#         }
#         normalized_vertices {
#           x: 0.0523076914
#           y: 0.399886221
#         }
#         normalized_vertices {
#           x: 0.113406591
#           y: 0.399886221
#         }
#         normalized_vertices {
#           x: 0.113406591
#           y: 0.41126281
#         }
#         normalized_vertices {
#           x: 0.0523076914
#           y: 0.41126281
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 389
#           end_index: 415
#         }
#       }
#       confidence: 0.966706693
#       bounding_poly {
#         vertices {
#           x: 351
#           y: 702
#         }
#         vertices {
#           x: 674
#           y: 702
#         }
#         vertices {
#           x: 674
#           y: 725
#         }
#         vertices {
#           x: 351
#           y: 725
#         }
#         normalized_vertices {
#           x: 0.154285714
#           y: 0.399317414
#         }
#         normalized_vertices {
#           x: 0.296263725
#           y: 0.399317414
#         }
#         normalized_vertices {
#           x: 0.296263725
#           y: 0.412400454
#         }
#         normalized_vertices {
#           x: 0.154285714
#           y: 0.412400454
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 415
#           end_index: 425
#         }
#       }
#       confidence: 0.974274635
#       bounding_poly {
#         vertices {
#           x: 739
#           y: 701
#         }
#         vertices {
#           x: 845
#           y: 700
#         }
#         vertices {
#           x: 845
#           y: 723
#         }
#         vertices {
#           x: 739
#           y: 724
#         }
#         normalized_vertices {
#           x: 0.324835151
#           y: 0.398748577
#         }
#         normalized_vertices {
#           x: 0.371428579
#           y: 0.39817974
#         }
#         normalized_vertices {
#           x: 0.371428579
#           y: 0.41126281
#         }
#         normalized_vertices {
#           x: 0.324835151
#           y: 0.411831617
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 425
#           end_index: 435
#         }
#       }
#       confidence: 0.970531821
#       bounding_poly {
#         vertices {
#           x: 1464
#           y: 702
#         }
#         vertices {
#           x: 1589
#           y: 701
#         }
#         vertices {
#           x: 1589
#           y: 725
#         }
#         vertices {
#           x: 1464
#           y: 726
#         }
#         normalized_vertices {
#           x: 0.643516481
#           y: 0.399317414
#         }
#         normalized_vertices {
#           x: 0.698461533
#           y: 0.398748577
#         }
#         normalized_vertices {
#           x: 0.698461533
#           y: 0.412400454
#         }
#         normalized_vertices {
#           x: 0.643516481
#           y: 0.412969291
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 435
#           end_index: 442
#         }
#       }
#       confidence: 0.9888587
#       bounding_poly {
#         vertices {
#           x: 1670
#           y: 703
#         }
#         vertices {
#           x: 1756
#           y: 701
#         }
#         vertices {
#           x: 1756
#           y: 721
#         }
#         vertices {
#           x: 1670
#           y: 723
#         }
#         normalized_vertices {
#           x: 0.73406595
#           y: 0.399886221
#         }
#         normalized_vertices {
#           x: 0.77186811
#           y: 0.398748577
#         }
#         normalized_vertices {
#           x: 0.77186811
#           y: 0.410125136
#         }
#         normalized_vertices {
#           x: 0.73406595
#           y: 0.41126281
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 442
#           end_index: 447
#         }
#       }
#       confidence: 0.986063242
#       bounding_poly {
#         vertices {
#           x: 1877
#           y: 703
#         }
#         vertices {
#           x: 1931
#           y: 703
#         }
#         vertices {
#           x: 1931
#           y: 722
#         }
#         vertices {
#           x: 1877
#           y: 722
#         }
#         normalized_vertices {
#           x: 0.825054944
#           y: 0.399886221
#         }
#         normalized_vertices {
#           x: 0.848791182
#           y: 0.399886221
#         }
#         normalized_vertices {
#           x: 0.848791182
#           y: 0.410693973
#         }
#         normalized_vertices {
#           x: 0.825054944
#           y: 0.410693973
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 447
#           end_index: 454
#         }
#       }
#       confidence: 0.959712148
#       bounding_poly {
#         vertices {
#           x: 2083
#           y: 702
#         }
#         vertices {
#           x: 2167
#           y: 701
#         }
#         vertices {
#           x: 2167
#           y: 723
#         }
#         vertices {
#           x: 2083
#           y: 724
#         }
#         normalized_vertices {
#           x: 0.915604413
#           y: 0.399317414
#         }
#         normalized_vertices {
#           x: 0.952527463
#           y: 0.398748577
#         }
#         normalized_vertices {
#           x: 0.952527463
#           y: 0.41126281
#         }
#         normalized_vertices {
#           x: 0.915604413
#           y: 0.411831617
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 454
#           end_index: 473
#         }
#       }
#       confidence: 0.975164354
#       bounding_poly {
#         vertices {
#           x: 350
#           y: 742
#         }
#         vertices {
#           x: 582
#           y: 742
#         }
#         vertices {
#           x: 582
#           y: 763
#         }
#         vertices {
#           x: 350
#           y: 763
#         }
#         normalized_vertices {
#           x: 0.15384616
#           y: 0.422070533
#         }
#         normalized_vertices {
#           x: 0.255824178
#           y: 0.422070533
#         }
#         normalized_vertices {
#           x: 0.255824178
#           y: 0.43401593
#         }
#         normalized_vertices {
#           x: 0.15384616
#           y: 0.43401593
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 473
#           end_index: 648
#         }
#       }
#       confidence: 0.981214464
#       bounding_poly {
#         vertices {
#           x: 933
#           y: 702
#         }
#         vertices {
#           x: 1433
#           y: 702
#         }
#         vertices {
#           x: 1433
#           y: 955
#         }
#         vertices {
#           x: 933
#           y: 955
#         }
#         normalized_vertices {
#           x: 0.410109878
#           y: 0.399317414
#         }
#         normalized_vertices {
#           x: 0.629890084
#           y: 0.399317414
#         }
#         normalized_vertices {
#           x: 0.629890084
#           y: 0.543230951
#         }
#         normalized_vertices {
#           x: 0.410109878
#           y: 0.543230951
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 648
#           end_index: 658
#         }
#       }
#       confidence: 0.985980153
#       bounding_poly {
#         vertices {
#           x: 119
#           y: 974
#         }
#         vertices {
#           x: 256
#           y: 973
#         }
#         vertices {
#           x: 256
#           y: 993
#         }
#         vertices {
#           x: 119
#           y: 994
#         }
#         normalized_vertices {
#           x: 0.0523076914
#           y: 0.554038703
#         }
#         normalized_vertices {
#           x: 0.112527475
#           y: 0.553469837
#         }
#         normalized_vertices {
#           x: 0.112527475
#           y: 0.564846396
#         }
#         normalized_vertices {
#           x: 0.0523076914
#           y: 0.565415263
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 658
#           end_index: 684
#         }
#       }
#       confidence: 0.969478
#       bounding_poly {
#         vertices {
#           x: 350
#           y: 973
#         }
#         vertices {
#           x: 673
#           y: 973
#         }
#         vertices {
#           x: 673
#           y: 997
#         }
#         vertices {
#           x: 350
#           y: 997
#         }
#         normalized_vertices {
#           x: 0.15384616
#           y: 0.553469837
#         }
#         normalized_vertices {
#           x: 0.29582417
#           y: 0.553469837
#         }
#         normalized_vertices {
#           x: 0.29582417
#           y: 0.567121744
#         }
#         normalized_vertices {
#           x: 0.15384616
#           y: 0.567121744
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 684
#           end_index: 694
#         }
#       }
#       confidence: 0.957933784
#       bounding_poly {
#         vertices {
#           x: 739
#           y: 972
#         }
#         vertices {
#           x: 845
#           y: 974
#         }
#         vertices {
#           x: 845
#           y: 995
#         }
#         vertices {
#           x: 739
#           y: 993
#         }
#         normalized_vertices {
#           x: 0.324835151
#           y: 0.552901
#         }
#         normalized_vertices {
#           x: 0.371428579
#           y: 0.554038703
#         }
#         normalized_vertices {
#           x: 0.371428579
#           y: 0.56598407
#         }
#         normalized_vertices {
#           x: 0.324835151
#           y: 0.564846396
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 694
#           end_index: 727
#         }
#       }
#       confidence: 0.990084529
#       bounding_poly {
#         vertices {
#           x: 934
#           y: 973
#         }
#         vertices {
#           x: 1387
#           y: 973
#         }
#         vertices {
#           x: 1387
#           y: 997
#         }
#         vertices {
#           x: 934
#           y: 997
#         }
#         normalized_vertices {
#           x: 0.410549462
#           y: 0.553469837
#         }
#         normalized_vertices {
#           x: 0.609670341
#           y: 0.553469837
#         }
#         normalized_vertices {
#           x: 0.609670341
#           y: 0.567121744
#         }
#         normalized_vertices {
#           x: 0.410549462
#           y: 0.567121744
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 727
#           end_index: 732
#         }
#       }
#       confidence: 0.985885084
#       bounding_poly {
#         vertices {
#           x: 1463
#           y: 974
#         }
#         vertices {
#           x: 1518
#           y: 973
#         }
#         vertices {
#           x: 1518
#           y: 992
#         }
#         vertices {
#           x: 1463
#           y: 993
#         }
#         normalized_vertices {
#           x: 0.643076897
#           y: 0.554038703
#         }
#         normalized_vertices {
#           x: 0.667252719
#           y: 0.553469837
#         }
#         normalized_vertices {
#           x: 0.667252719
#           y: 0.564277589
#         }
#         normalized_vertices {
#           x: 0.643076897
#           y: 0.564846396
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 732
#           end_index: 739
#         }
#       }
#       confidence: 0.988006473
#       bounding_poly {
#         vertices {
#           x: 1669
#           y: 973
#         }
#         vertices {
#           x: 1756
#           y: 973
#         }
#         vertices {
#           x: 1756
#           y: 994
#         }
#         vertices {
#           x: 1669
#           y: 994
#         }
#         normalized_vertices {
#           x: 0.733626366
#           y: 0.553469837
#         }
#         normalized_vertices {
#           x: 0.77186811
#           y: 0.553469837
#         }
#         normalized_vertices {
#           x: 0.77186811
#           y: 0.565415263
#         }
#         normalized_vertices {
#           x: 0.733626366
#           y: 0.565415263
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 739
#           end_index: 744
#         }
#       }
#       confidence: 0.968508303
#       bounding_poly {
#         vertices {
#           x: 1877
#           y: 974
#         }
#         vertices {
#           x: 1931
#           y: 975
#         }
#         vertices {
#           x: 1931
#           y: 994
#         }
#         vertices {
#           x: 1877
#           y: 993
#         }
#         normalized_vertices {
#           x: 0.825054944
#           y: 0.554038703
#         }
#         normalized_vertices {
#           x: 0.848791182
#           y: 0.554607511
#         }
#         normalized_vertices {
#           x: 0.848791182
#           y: 0.565415263
#         }
#         normalized_vertices {
#           x: 0.825054944
#           y: 0.564846396
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 744
#           end_index: 751
#         }
#       }
#       confidence: 0.960440457
#       bounding_poly {
#         vertices {
#           x: 2083
#           y: 973
#         }
#         vertices {
#           x: 2167
#           y: 971
#         }
#         vertices {
#           x: 2167
#           y: 993
#         }
#         vertices {
#           x: 2083
#           y: 995
#         }
#         normalized_vertices {
#           x: 0.915604413
#           y: 0.553469837
#         }
#         normalized_vertices {
#           x: 0.952527463
#           y: 0.552332222
#         }
#         normalized_vertices {
#           x: 0.952527463
#           y: 0.564846396
#         }
#         normalized_vertices {
#           x: 0.915604413
#           y: 0.56598407
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 751
#           end_index: 770
#         }
#       }
#       confidence: 0.982661128
#       bounding_poly {
#         vertices {
#           x: 350
#           y: 1012
#         }
#         vertices {
#           x: 581
#           y: 1013
#         }
#         vertices {
#           x: 581
#           y: 1033
#         }
#         vertices {
#           x: 350
#           y: 1032
#         }
#         normalized_vertices {
#           x: 0.15384616
#           y: 0.575654149
#         }
#         normalized_vertices {
#           x: 0.255384624
#           y: 0.576222956
#         }
#         normalized_vertices {
#           x: 0.255384624
#           y: 0.587599516
#         }
#         normalized_vertices {
#           x: 0.15384616
#           y: 0.587030709
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 770
#           end_index: 797
#         }
#       }
#       confidence: 0.987752259
#       bounding_poly {
#         vertices {
#           x: 1101
#           y: 1011
#         }
#         vertices {
#           x: 1429
#           y: 1013
#         }
#         vertices {
#           x: 1429
#           y: 1037
#         }
#         vertices {
#           x: 1101
#           y: 1035
#         }
#         normalized_vertices {
#           x: 0.483956039
#           y: 0.575085342
#         }
#         normalized_vertices {
#           x: 0.628131866
#           y: 0.576222956
#         }
#         normalized_vertices {
#           x: 0.628131866
#           y: 0.589874864
#         }
#         normalized_vertices {
#           x: 0.483956039
#           y: 0.58873719
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 797
#           end_index: 818
#         }
#       }
#       confidence: 0.978180051
#       bounding_poly {
#         vertices {
#           x: 1101
#           y: 1050
#         }
#         vertices {
#           x: 1343
#           y: 1048
#         }
#         vertices {
#           x: 1343
#           y: 1070
#         }
#         vertices {
#           x: 1101
#           y: 1072
#         }
#         normalized_vertices {
#           x: 0.483956039
#           y: 0.597269654
#         }
#         normalized_vertices {
#           x: 0.590329647
#           y: 0.596132
#         }
#         normalized_vertices {
#           x: 0.590329647
#           y: 0.608646214
#         }
#         normalized_vertices {
#           x: 0.483956039
#           y: 0.609783828
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 818
#           end_index: 828
#         }
#       }
#       confidence: 0.98668164
#       bounding_poly {
#         vertices {
#           x: 119
#           y: 1158
#         }
#         vertices {
#           x: 258
#           y: 1158
#         }
#         vertices {
#           x: 258
#           y: 1178
#         }
#         vertices {
#           x: 119
#           y: 1178
#         }
#         normalized_vertices {
#           x: 0.0523076914
#           y: 0.658703089
#         }
#         normalized_vertices {
#           x: 0.113406591
#           y: 0.658703089
#         }
#         normalized_vertices {
#           x: 0.113406591
#           y: 0.670079648
#         }
#         normalized_vertices {
#           x: 0.0523076914
#           y: 0.670079648
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 828
#           end_index: 854
#         }
#       }
#       confidence: 0.973542452
#       bounding_poly {
#         vertices {
#           x: 351
#           y: 1157
#         }
#         vertices {
#           x: 674
#           y: 1157
#         }
#         vertices {
#           x: 674
#           y: 1180
#         }
#         vertices {
#           x: 351
#           y: 1180
#         }
#         normalized_vertices {
#           x: 0.154285714
#           y: 0.658134222
#         }
#         normalized_vertices {
#           x: 0.296263725
#           y: 0.658134222
#         }
#         normalized_vertices {
#           x: 0.296263725
#           y: 0.671217263
#         }
#         normalized_vertices {
#           x: 0.154285714
#           y: 0.671217263
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 854
#           end_index: 864
#         }
#       }
#       confidence: 0.979299426
#       bounding_poly {
#         vertices {
#           x: 739
#           y: 1158
#         }
#         vertices {
#           x: 846
#           y: 1158
#         }
#         vertices {
#           x: 846
#           y: 1179
#         }
#         vertices {
#           x: 739
#           y: 1179
#         }
#         normalized_vertices {
#           x: 0.324835151
#           y: 0.658703089
#         }
#         normalized_vertices {
#           x: 0.371868134
#           y: 0.658703089
#         }
#         normalized_vertices {
#           x: 0.371868134
#           y: 0.670648456
#         }
#         normalized_vertices {
#           x: 0.324835151
#           y: 0.670648456
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 864
#           end_index: 873
#         }
#       }
#       confidence: 0.986080468
#       bounding_poly {
#         vertices {
#           x: 1671
#           y: 1158
#         }
#         vertices {
#           x: 1779
#           y: 1156
#         }
#         vertices {
#           x: 1779
#           y: 1179
#         }
#         vertices {
#           x: 1671
#           y: 1181
#         }
#         normalized_vertices {
#           x: 0.734505475
#           y: 0.658703089
#         }
#         normalized_vertices {
#           x: 0.781978
#           y: 0.657565415
#         }
#         normalized_vertices {
#           x: 0.781978
#           y: 0.670648456
#         }
#         normalized_vertices {
#           x: 0.734505475
#           y: 0.671786129
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 873
#           end_index: 878
#         }
#       }
#       confidence: 0.984989
#       bounding_poly {
#         vertices {
#           x: 1876
#           y: 1158
#         }
#         vertices {
#           x: 1932
#           y: 1157
#         }
#         vertices {
#           x: 1932
#           y: 1177
#         }
#         vertices {
#           x: 1876
#           y: 1178
#         }
#         normalized_vertices {
#           x: 0.824615359
#           y: 0.658703089
#         }
#         normalized_vertices {
#           x: 0.849230766
#           y: 0.658134222
#         }
#         normalized_vertices {
#           x: 0.849230766
#           y: 0.669510782
#         }
#         normalized_vertices {
#           x: 0.824615359
#           y: 0.670079648
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 878
#           end_index: 883
#         }
#       }
#       confidence: 0.923177302
#       bounding_poly {
#         vertices {
#           x: 2083
#           y: 1158
#         }
#         vertices {
#           x: 2153
#           y: 1159
#         }
#         vertices {
#           x: 2152
#           y: 1184
#         }
#         vertices {
#           x: 2082
#           y: 1183
#         }
#         normalized_vertices {
#           x: 0.915604413
#           y: 0.658703089
#         }
#         normalized_vertices {
#           x: 0.946373641
#           y: 0.659271896
#         }
#         normalized_vertices {
#           x: 0.945934057
#           y: 0.67349261
#         }
#         normalized_vertices {
#           x: 0.915164828
#           y: 0.672923803
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 883
#           end_index: 955
#         }
#       }
#       confidence: 0.971376657
#       bounding_poly {
#         vertices {
#           x: 931
#           y: 1156
#         }
#         vertices {
#           x: 1575
#           y: 1156
#         }
#         vertices {
#           x: 1575
#           y: 1218
#         }
#         vertices {
#           x: 931
#           y: 1218
#         }
#         normalized_vertices {
#           x: 0.409230769
#           y: 0.657565415
#         }
#         normalized_vertices {
#           x: 0.692307711
#           y: 0.657565415
#         }
#         normalized_vertices {
#           x: 0.692307711
#           y: 0.692832768
#         }
#         normalized_vertices {
#           x: 0.409230769
#           y: 0.692832768
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 955
#           end_index: 974
#         }
#       }
#       confidence: 0.98012948
#       bounding_poly {
#         vertices {
#           x: 351
#           y: 1197
#         }
#         vertices {
#           x: 581
#           y: 1197
#         }
#         vertices {
#           x: 581
#           y: 1217
#         }
#         vertices {
#           x: 351
#           y: 1217
#         }
#         normalized_vertices {
#           x: 0.154285714
#           y: 0.680887401
#         }
#         normalized_vertices {
#           x: 0.255384624
#           y: 0.680887401
#         }
#         normalized_vertices {
#           x: 0.255384624
#           y: 0.692263961
#         }
#         normalized_vertices {
#           x: 0.154285714
#           y: 0.692263961
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 974
#           end_index: 991
#         }
#       }
#       confidence: 0.955355763
#       bounding_poly {
#         vertices {
#           x: 2031
#           y: 1585
#         }
#         vertices {
#           x: 2172
#           y: 1586
#         }
#         vertices {
#           x: 2171
#           y: 1651
#         }
#         vertices {
#           x: 2030
#           y: 1650
#         }
#         normalized_vertices {
#           x: 0.892747223
#           y: 0.901592731
#         }
#         normalized_vertices {
#           x: 0.954725266
#           y: 0.902161539
#         }
#         normalized_vertices {
#           x: 0.954285741
#           y: 0.939135373
#         }
#         normalized_vertices {
#           x: 0.892307699
#           y: 0.938566566
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 11
#         }
#       }
#       confidence: 0.972773612
#       bounding_poly {
#         vertices {
#           x: 318
#           y: 174
#         }
#         vertices {
#           x: 927
#           y: 186
#         }
#         vertices {
#           x: 925
#           y: 268
#         }
#         vertices {
#           x: 316
#           y: 256
#         }
#         normalized_vertices {
#           x: 0.139780223
#           y: 0.0989761129
#         }
#         normalized_vertices {
#           x: 0.407472521
#           y: 0.105802044
#         }
#         normalized_vertices {
#           x: 0.406593412
#           y: 0.152445957
#         }
#         normalized_vertices {
#           x: 0.1389011
#           y: 0.145620018
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 11
#           end_index: 30
#         }
#       }
#       confidence: 0.981170893
#       bounding_poly {
#         vertices {
#           x: 1309
#           y: 159
#         }
#         vertices {
#           x: 1914
#           y: 173
#         }
#         vertices {
#           x: 1913
#           y: 231
#         }
#         vertices {
#           x: 1308
#           y: 217
#         }
#         normalized_vertices {
#           x: 0.575384617
#           y: 0.0904436857
#         }
#         normalized_vertices {
#           x: 0.841318667
#           y: 0.0984072834
#         }
#         normalized_vertices {
#           x: 0.840879142
#           y: 0.131399319
#         }
#         normalized_vertices {
#           x: 0.574945033
#           y: 0.123435721
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 30
#           end_index: 43
#         }
#       }
#       confidence: 0.985181749
#       bounding_poly {
#         vertices {
#           x: 1488
#           y: 252
#         }
#         vertices {
#           x: 1739
#           y: 259
#         }
#         vertices {
#           x: 1738
#           y: 295
#         }
#         vertices {
#           x: 1487
#           y: 288
#         }
#         normalized_vertices {
#           x: 0.654065907
#           y: 0.143344715
#         }
#         normalized_vertices {
#           x: 0.764395595
#           y: 0.147326514
#         }
#         normalized_vertices {
#           x: 0.76395607
#           y: 0.167804316
#         }
#         normalized_vertices {
#           x: 0.653626382
#           y: 0.163822532
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 43
#           end_index: 80
#         }
#       }
#       confidence: 0.983066082
#       bounding_poly {
#         vertices {
#           x: 325
#           y: 281
#         }
#         vertices {
# ...
#     mime_type: "image/png"
#     width: 2275
#     height: 1758
#   }
# }
# entities {
#   type_: "generic_entities"
#   page_anchor {
#     page_refs {
#     }
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 11
#         end_index: 29
#       }
#     }
#     type_: "organization"
#     mention_text: "Risk Point Program"
#     confidence: 0.55756712
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.574945033
#             y: 0.0904436857
#           }
#           normalized_vertices {
#             x: 0.841318667
#             y: 0.0904436857
#           }
#           normalized_vertices {
#             x: 0.841318667
#             y: 0.130830497
#           }
#           normalized_vertices {
#             x: 0.574945033
#             y: 0.130830497
#           }
#         }
#       }
#     }
#     id: "0"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 89
#         end_index: 133
#       }
#     }
#     type_: "organization"
#     mention_text: "Stoler of Queens, Inc dba Silver Star Motors"
#     confidence: 0.983754456
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.269450545
#             y: 0.218998864
#           }
#           normalized_vertices {
#             x: 0.516483545
#             y: 0.218998864
#           }
#           normalized_vertices {
#             x: 0.516483545
#             y: 0.232650742
#           }
#           normalized_vertices {
#             x: 0.269450545
#             y: 0.232650742
#           }
#         }
#       }
#     }
#     id: "1"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 145
#         end_index: 154
#       }
#     }
#     type_: "id"
#     mention_text: "100046290"
#     confidence: 0.994942665
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.270329684
#             y: 0.242320821
#           }
#           normalized_vertices {
#             x: 0.332747251
#             y: 0.242320821
#           }
#           normalized_vertices {
#             x: 0.332747251
#             y: 0.253128558
#           }
#           normalized_vertices {
#             x: 0.270329684
#             y: 0.253128558
#           }
#         }
#       }
#     }
#     id: "2"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 222
#         end_index: 244
#       }
#     }
#     type_: "date_time"
#     mention_text: "3/28/2024 to 3/28/2025"
#     confidence: 0.993544161
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.269450545
#             y: 0.287258238
#           }
#           normalized_vertices {
#             x: 0.407472521
#             y: 0.287258238
#           }
#           normalized_vertices {
#             x: 0.407472521
#             y: 0.301478952
#           }
#           normalized_vertices {
#             x: 0.269450545
#             y: 0.301478952
#           }
#         }
#       }
#     }
#     id: "3"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 245
#         end_index: 253
#       }
#     }
#     type_: "date_time"
#     mention_text: "9/4/2024"
#     confidence: 0.988056
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.269450545
#             y: 0.310011387
#           }
#           normalized_vertices {
#             x: 0.322197795
#             y: 0.310011387
#           }
#           normalized_vertices {
#             x: 0.322197795
#             y: 0.323663265
#           }
#           normalized_vertices {
#             x: 0.269450545
#             y: 0.323663265
#           }
#         }
#       }
#     }
#     id: "4"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 379
#         end_index: 388
#       }
#     }
#     type_: "id"
#     mention_text: "907885-CB"
#     confidence: 0.987943053
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.0523076914
#             y: 0.399886221
#           }
#           normalized_vertices {
#             x: 0.113406591
#             y: 0.399886221
#           }
#           normalized_vertices {
#             x: 0.113406591
#             y: 0.41126281
#           }
#           normalized_vertices {
#             x: 0.0523076914
#             y: 0.41126281
#           }
#         }
#       }
#     }
#     id: "5"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 389
#         end_index: 414
#       }
#     }
#     type_: "organization"
#     mention_text: "Stoler of Queens, Inc dba"
#     confidence: 0.963346839
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.154285714
#             y: 0.399317414
#           }
#           normalized_vertices {
#             x: 0.296263725
#             y: 0.399317414
#           }
#           normalized_vertices {
#             x: 0.296263725
#             y: 0.412400454
#           }
#           normalized_vertices {
#             x: 0.154285714
#             y: 0.412400454
#           }
#         }
#       }
#     }
#     id: "6"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 425
#         end_index: 434
#       }
#     }
#     type_: "price"
#     mention_text: "17,143.90"
#     confidence: 0.968722522
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.643516481
#             y: 0.398748577
#           }
#           normalized_vertices {
#             x: 0.698461533
#             y: 0.398748577
#           }
#           normalized_vertices {
#             x: 0.698461533
#             y: 0.412969291
#           }
#           normalized_vertices {
#             x: 0.643516481
#             y: 0.412969291
#           }
#         }
#       }
#     }
#     id: "7"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 435
#         end_index: 441
#       }
#     }
#     type_: "price"
#     mention_text: "240.00"
#     confidence: 0.95430243
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.73406595
#             y: 0.398748577
#           }
#           normalized_vertices {
#             x: 0.77186811
#             y: 0.398748577
#           }
#           normalized_vertices {
#             x: 0.77186811
#             y: 0.41126281
#           }
#           normalized_vertices {
#             x: 0.73406595
#             y: 0.41126281
#           }
#         }
#       }
#     }
#     id: "8"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 442
#         end_index: 446
#       }
#     }
#     type_: "price"
#     mention_text: "0.00"
#     confidence: 0.934311926
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.825054944
#             y: 0.399886221
#           }
#           normalized_vertices {
#             x: 0.848791182
#             y: 0.399886221
#           }
#           normalized_vertices {
#             x: 0.848791182
#             y: 0.410693973
#           }
#           normalized_vertices {
#             x: 0.825054944
#             y: 0.410693973
#           }
#         }
#       }
#     }
#     id: "9"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 473
#         end_index: 482
#       }
#     }
#     type_: "date_time"
#     mention_text: "7/25/2024"
#     confidence: 0.995905042
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.410109878
#             y: 0.399317414
#           }
#           normalized_vertices {
#             x: 0.469890118
#             y: 0.399317414
#           }
#           normalized_vertices {
#             x: 0.469890118
#             y: 0.414675772
#           }
#           normalized_vertices {
#             x: 0.410109878
#             y: 0.414675772
#           }
#         }
#       }
#     }
#     id: "10"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 658
#         end_index: 679
#       }
#     }
#     type_: "organization"
#     mention_text: "Stoler of Queens, Inc"
#     confidence: 0.957935691
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.15384616
#             y: 0.553469837
#           }
#           normalized_vertices {
#             x: 0.272527486
#             y: 0.553469837
#           }
#           normalized_vertices {
#             x: 0.272527486
#             y: 0.567121744
#           }
#           normalized_vertices {
#             x: 0.15384616
#             y: 0.567121744
#           }
#         }
#       }
#     }
#     id: "11"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 694
#         end_index: 703
#       }
#     }
#     type_: "date_time"
#     mention_text: "6/21/2024"
#     confidence: 0.996876121
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.410549462
#             y: 0.553469837
#           }
#           normalized_vertices {
#             x: 0.469890118
#             y: 0.553469837
#           }
#           normalized_vertices {
#             x: 0.469890118
#             y: 0.567121744
#           }
#           normalized_vertices {
#             x: 0.410549462
#             y: 0.567121744
#           }
#         }
#       }
#     }
#     id: "12"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 727
#         end_index: 731
#       }
#     }
#     type_: "price"
#     mention_text: "0.00"
#     confidence: 0.862361729
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.643076897
#             y: 0.553469837
#           }
#           normalized_vertices {
#             x: 0.667252719
#             y: 0.553469837
#           }
#           normalized_vertices {
#             x: 0.667252719
#             y: 0.564846396
#           }
#           normalized_vertices {
#             x: 0.643076897
#             y: 0.564846396
#           }
#         }
#       }
#     }
#     id: "13"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 732
#         end_index: 738
#       }
#     }
#     type_: "price"
#     mention_text: "400.00"
#     confidence: 0.980429888
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.733626366
#             y: 0.553469837
#           }
#           normalized_vertices {
#             x: 0.77186811
#             y: 0.553469837
#           }
#           normalized_vertices {
#             x: 0.77186811
#             y: 0.565415263
#           }
#           normalized_vertices {
#             x: 0.733626366
#             y: 0.565415263
#           }
#         }
#       }
#     }
#     id: "14"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 739
#         end_index: 743
#       }
#     }
#     type_: "price"
#     mention_text: "0.00"
#     confidence: 0.973970711
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.825054944
#             y: 0.554038703
#           }
#           normalized_vertices {
#             x: 0.848791182
#             y: 0.554038703
#           }
#           normalized_vertices {
#             x: 0.848791182
#             y: 0.565415263
#           }
#           normalized_vertices {
#             x: 0.825054944
#             y: 0.565415263
#           }
#         }
#       }
#     }
#     id: "15"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 828
#         end_index: 849
#       }
#     }
#     type_: "organization"
#     mention_text: "Stoler of Queens, Inc"
#     confidence: 0.958278835
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.154285714
#             y: 0.658134222
#           }
#           normalized_vertices {
#             x: 0.272527486
#             y: 0.658134222
#           }
#           normalized_vertices {
#             x: 0.272527486
#             y: 0.671217263
#           }
#           normalized_vertices {
#             x: 0.154285714
#             y: 0.671217263
#           }
#         }
#       }
#     }
#     id: "16"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 864
#         end_index: 872
#       }
#     }
#     type_: "price"
#     mention_text: "1,300.00"
#     confidence: 0.988095164
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.734505475
#             y: 0.657565415
#           }
#           normalized_vertices {
#             x: 0.781978
#             y: 0.657565415
#           }
#           normalized_vertices {
#             x: 0.781978
#             y: 0.671786129
#           }
#           normalized_vertices {
#             x: 0.734505475
#             y: 0.671786129
#           }
#         }
#       }
#     }
#     id: "17"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 873
#         end_index: 877
#       }
#     }
#     type_: "price"
#     mention_text: "0.00"
#     confidence: 0.977521956
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.824615359
#             y: 0.658134222
#           }
#           normalized_vertices {
#             x: 0.849230766
#             y: 0.658134222
#           }
#           normalized_vertices {
#             x: 0.849230766
#             y: 0.670079648
#           }
#           normalized_vertices {
#             x: 0.824615359
#             y: 0.670079648
#           }
#         }
#       }
#     }
#     id: "18"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 883
#         end_index: 892
#       }
#     }
#     type_: "date_time"
#     mention_text: "4/23/2024"
#     confidence: 0.996838331
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.409230769
#             y: 0.657565415
#           }
#           normalized_vertices {
#             x: 0.469890118
#             y: 0.657565415
#           }
#           normalized_vertices {
#             x: 0.469890118
#             y: 0.672354937
#           }
#           normalized_vertices {
#             x: 0.409230769
#             y: 0.672354937
#           }
#         }
#       }
#     }
#     id: "19"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 918
#         end_index: 926
#       }
#     }
#     type_: "price"
#     mention_text: "6,262.12"
#     confidence: 0.932620943
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.643516481
#             y: 0.657565415
#           }
#           normalized_vertices {
#             x: 0.692307711
#             y: 0.657565415
#           }
#           normalized_vertices {
#             x: 0.692307711
#             y: 0.672354937
#           }
#           normalized_vertices {
#             x: 0.643516481
#             y: 0.672354937
#           }
#         }
#       }
#     }
#     id: "20"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 982
#         end_index: 990
#       }
#     }
#     type_: "date_time"
#     mention_text: "9/4/2024"
#     confidence: 0.957787097
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.901098907
#             y: 0.923208177
#           }
#           normalized_vertices {
#             x: 0.954725266
#             y: 0.923208177
#           }
#           normalized_vertices {
#             x: 0.954725266
#             y: 0.939135373
#           }
#           normalized_vertices {
#             x: 0.901098907
#             y: 0.939135373
#           }
#         }
#       }
#     }
#     id: "21"
#   }
# }

# %%
from google.cloud import documentai_v1 as docai
from google.oauth2 import service_account
import os
from typing import Iterator, MutableSequence, Optional, Sequence, Tuple, List
from tabulate import tabulate
import pandas as pd

def table_extraction(
    document: docai.Document
) -> List[pd.DataFrame]:
    '''
    Function to extract tables from document AI output
    '''
    # Extract document text
    full_text = document.text
    tables_as_dataframes = []

    # Iterate over available pages and handle each available table
    for page_index, page in enumerate(document.pages):
        print(f"\n--- Page {page_index + 1} ---\n")

        for table_index, table in enumerate(page.tables):
            print(f"Table {table_index + 1}:")
            # Extract and print header and body rows
            headers = extract_table_rows(table.header_rows, full_text)
            body = extract_table_rows(table.body_rows, full_text)

            # Use the first header row (if available) as column names
            if headers:
                df = pd.DataFrame(body, columns=headers[0])
            else:
                # If no headers, create generic column names
                num_columns = max(len(row) for row in body) if body else 0
                df = pd.DataFrame(body, columns=[f"Column {i+1}" for i in range(num_columns)])
            
            # Append the DataFrame for this table
            tables_as_dataframes.append(df)
    
    return tables_as_dataframes

def extract_table_rows(
    table_rows: Sequence[docai.Document.Page.Table.TableRow], text: str
) -> List[List[str]]:
    '''
    Extracts rows of text from Document AI table rows
    '''
    rows = []
    for table_row in table_rows:
        row_data = []
        for cell in table_row.cells:
            cell_text = layout_to_text(cell.layout, text).strip()
            row_data.append(cell_text)
        rows.append(row_data)
    return rows

def layout_to_text(layout: docai.Document.Page.Layout, text: str) -> str:
    """
    Document AI identifies text in different parts of the document by their
    offsets in the entirety of the document"s text. This function converts
    offsets to a string.
    """
    # If a text segment spans several lines, it will
    # be stored in different text segments.
    return "".join(
        text[int(segment.start_index) : int(segment.end_index)]
        for segment in layout.text_anchor.text_segments
    )

# %%
dfs = table_extraction(document)
# Out:
# --- Page 1 ---
#
# Table 1:
# Table 2:

# %%
dfs[1]
# Out:
#   Claim Number                                   Insured Name Cause of\nLoss  \
# 0    907885-CB  Stoler of Queens, Inc dba\nSilver Star Motors      Collision
# 1    907814-CB  Stoler of Queens, Inc dba\nSilver Star Motors      Collision
# 2    907812-CB  Stoler of Queens, Inc dba\nSilver Star Motors      Collision
#
#   Date of\nLoss                            Description of Accident  Indemnity  \
# 0     7/25/2024  IVD trying to park vehicle\nin stacker lift th...  17,143.90
# 1     6/21/2024  Rental was involved in\ncollision while being ...       0.00
# 2     4/23/2024  Customer was involved in a collision while in ...   6,262.12
#
#     Expense Recovery  Status
# 0    240.00     0.00  Closed
# 1    400.00     0.00  Closed
# 2  1,300.00     0.00    Open
